# %% [markdown]
# # Group 47
# Woosung Do, Kavin Inthirakot, Josue Quichiz

# %% [markdown]
# ## MGS 314 Investment Chart
# # Electric Vehicle Industry
# Fisker INC(FSR), General Motors(GM),Lucid Group(LCID)

# %% [markdown]
# ###  Import Packages

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
import yfinance as yf

from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.dates as mdates

# %% [markdown]
# ### Data preprocessing

# %%
style.use('seaborn')

# %%
start = dt.datetime(2021,1,1)
end = dt.datetime(2021,12,31)

# %% [markdown]
# ### save the data as a csv file

# %%
df_FSR= web.DataReader('FSR', 'yahoo', start, end)
df_FSR.to_csv('FSR.csv')

# %%
df_GM= web.DataReader('GM', 'yahoo', start, end)
df_GM.to_csv('GM.csv')

# %%
df_LCID= web.DataReader('LCID', 'yahoo', start, end)
df_LCID.to_csv('LCID.csv')

# %%
df_FSR = pd.read_csv('FSR.csv', parse_dates=True, index_col=0)
df_GM = pd.read_csv('GM.csv', parse_dates=True, index_col=0)
df_LCID = pd.read_csv('LCID.csv', parse_dates=True, index_col=0)

# %%
pd.set_option("display.precision", 2)

# %%
print(df_FSR[['Volume', 'Adj Close']])
# Out:
#               Volume  Adj Close
# Date
# 2021-01-04   7718000      15.19
# 2021-01-05   3933300      15.40
# 2021-01-06   6642300      15.25
# 2021-01-07   5617400      15.65
# 2021-01-08   7992800      15.24
# ...              ...        ...
# 2021-12-01  13040700      19.77
# 2021-12-02  11564300      18.99
# 2021-12-03  13322900      17.62
# 2021-12-06   9946200      17.28
# 2021-12-07   6388088      18.49
#
# [235 rows x 2 columns]

# %%
print(df_GM[['Volume', 'Adj Close']])
# Out:
#               Volume  Adj Close
# Date
# 2021-01-04  15768100      40.51
# 2021-01-05  18045800      41.66
# 2021-01-06  22694900      42.98
# 2021-01-07  13625700      43.32
# 2021-01-08  18426200      43.06
# ...              ...        ...
# 2021-12-01  26353700      58.06
# 2021-12-02  25365100      61.02
# 2021-12-03  19582800      59.71
# 2021-12-06  16718500      59.84
# 2021-12-07   8392421      61.88
#
# [235 rows x 2 columns]

# %%
print(df_LCID[['Volume', 'Adj Close']])
# Out:
#                Volume  Adj Close
# Date
# 2021-01-04    1172700      10.04
# 2021-01-05     685700      10.02
# 2021-01-06     636600      10.01
# 2021-01-07    1075500      10.03
# 2021-01-08     738200      10.03
# ...               ...        ...
# 2021-12-01   78654100      51.14
# 2021-12-02   77168500      48.41
# 2021-12-03   76351400      47.27
# 2021-12-06  103833200      44.86
# 2021-12-07   45811381      44.22
#
# [235 rows x 2 columns]

# %%
df_FSR.plot()

# %%
df_GM.plot()

# %%
df_LCID.plot()

# %%
df_FSR['Adj Close'].plot()
plt.title('FSR Adj Close')
# Out:
# Text(0.5, 1.0, 'FSR Adj Close')

# %%
df_GM['Adj Close'].plot()
plt.title('GM Adj Close')
# Out:
# Text(0.5, 1.0, 'GM Adj Close')

# %%
df_LCID['Adj Close'].plot()
plt.title('GM Adj Close')
# Out:
# Text(0.5, 1.0, 'GM Adj Close')

# %% [markdown]
# ### Table with statistics for High, Low and Adjusted Close prices and volume by date

# %%
df_table_FSR=df_FSR[['High','Low','Adj Close','Volume']]
df_table_FSR
# Out:
#              High    Low  Adj Close    Volume
# Date
# 2021-01-04  15.33  14.56      15.19   7718000
# 2021-01-05  15.70  14.84      15.40   3933300
# 2021-01-06  15.90  15.03      15.25   6642300
# 2021-01-07  16.05  15.42      15.65   5617400
# 2021-01-08  16.15  14.95      15.24   7992800
# ...           ...    ...        ...       ...
# 2021-12-01  22.64  19.74      19.77  13040700
# 2021-12-02  20.24  18.37      18.99  11564300
# 2021-12-03  18.85  17.02      17.62  13322900
# 2021-12-06  17.98  16.27      17.28   9946200
# 2021-12-07  18.59  17.68      18.49   6388088
#
# [235 rows x 4 columns]

# %%
df_table_GM=df_GM[['High','Low','Adj Close','Volume']]
df_table_GM
# Out:
#              High    Low  Adj Close    Volume
# Date
# 2021-01-04  42.12  40.14      40.51  15768100
# 2021-01-05  41.84  40.04      41.66  18045800
# 2021-01-06  43.85  41.86      42.98  22694900
# 2021-01-07  43.98  42.96      43.32  13625700
# 2021-01-08  43.49  42.32      43.06  18426200
# ...           ...    ...        ...       ...
# 2021-12-01  60.59  58.01      58.06  26353700
# 2021-12-02  61.30  58.70      61.02  25365100
# 2021-12-03  61.69  58.87      59.71  19582800
# 2021-12-06  60.73  58.70      59.84  16718500
# 2021-12-07  62.38  60.70      61.88   8392421
#
# [235 rows x 4 columns]

# %%
df_table_LCID=df_LCID[['High','Low','Adj Close','Volume']]
df_table_LCID
# Out:
#              High    Low  Adj Close     Volume
# Date
# 2021-01-04  10.08  10.02      10.04    1172700
# 2021-01-05  10.04  10.00      10.02     685700
# 2021-01-06  10.02  10.00      10.01     636600
# 2021-01-07  10.04  10.00      10.03    1075500
# 2021-01-08  10.05  10.02      10.03     738200
# ...           ...    ...        ...        ...
# 2021-12-01  56.24  50.95      51.14   78654100
# 2021-12-02  51.84  46.02      48.41   77168500
# 2021-12-03  49.49  44.57      47.27   76351400
# 2021-12-06  45.75  38.06      44.86  103833200
# 2021-12-07  47.21  43.02      44.22   45811381
#
# [235 rows x 4 columns]

# %% [markdown]
# ### Calculating 100 day moving average for the Adjusted Close

# %%
close_FSR=df_FSR['Adj Close']
df_FSR['100ma'] = close_FSR.rolling(window=100,min_periods = 0).mean()
sma_FSR=df_FSR['100ma']
df_FSR.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close  100ma
# Date
# 2021-01-04  15.33  14.56  15.21  15.19  7718000      15.19  15.19
# 2021-01-05  15.70  14.84  14.92  15.40  3933300      15.40  15.29
# 2021-01-06  15.90  15.03  15.26  15.25  6642300      15.25  15.28
# 2021-01-07  16.05  15.42  15.75  15.65  5617400      15.65  15.37
# 2021-01-08  16.15  14.95  15.80  15.24  7992800      15.24  15.35

# %%
close_GM=df_GM['Adj Close']
df_GM['100ma'] = close_GM.rolling(window=100,min_periods = 0).mean()
sma_GM=df_GM['100ma']
df_GM.head()
# Out:
#              High    Low   Open  Close    Volume  Adj Close  100ma
# Date
# 2021-01-04  42.12  40.14  41.95  40.51  15768100      40.51  40.51
# 2021-01-05  41.84  40.04  40.06  41.66  18045800      41.66  41.08
# 2021-01-06  43.85  41.86  41.92  42.98  22694900      42.98  41.72
# 2021-01-07  43.98  42.96  43.98  43.32  13625700      43.32  42.12
# 2021-01-08  43.49  42.32  43.31  43.06  18426200      43.06  42.31

# %%
close_LCID=df_LCID['Adj Close']
df_LCID['100ma'] = close_LCID.rolling(window=100,min_periods = 0).mean()
sma_LCID=df_LCID['100ma']
df_LCID.head()
# Out:
#              High    Low   Open  Close   Volume  Adj Close  100ma
# Date
# 2021-01-04  10.08  10.02  10.03  10.04  1172700      10.04  10.04
# 2021-01-05  10.04  10.00  10.04  10.02   685700      10.02  10.03
# 2021-01-06  10.02  10.00  10.00  10.01   636600      10.01  10.02
# 2021-01-07  10.04  10.00  10.00  10.03  1075500      10.03  10.03
# 2021-01-08  10.05  10.02  10.05  10.03   738200      10.03  10.03

# %% [markdown]
# ### Graph for Volume, the 100day and Adjusted close

# %%
ax1=plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
plt.title('FSR Stock Trend')
ax2=plt.subplot2grid((8,1),(6,0),rowspan=1,colspan=1)
plt.title('FSR Moving Volume')
ax1.plot(df_FSR.index,df_FSR['Adj Close'])
ax1.plot(df_FSR.index,df_FSR['100ma'])
ax2.bar(df_FSR.index,df_FSR['Volume'])
# Out:
# <BarContainer object of 235 artists>

# %%
ax1=plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
plt.title('GM Stock Trend')
ax2=plt.subplot2grid((8,1),(6,0),rowspan=1,colspan=1)
plt.title('GM Moving Volume')
ax1.plot(df_GM.index,df_GM['Adj Close'])
ax1.plot(df_GM.index,df_GM['100ma'])
ax2.bar(df_GM.index,df_GM['Volume'])
# Out:
# <BarContainer object of 235 artists>

# %%
ax1=plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
plt.title('LCID Stock Trend')
ax2=plt.subplot2grid((8,1),(6,0),rowspan=1,colspan=1)
plt.title('LCID Moving Volume')
ax1.plot(df_LCID.index,df_LCID['Adj Close'])
ax1.plot(df_LCID.index,df_LCID['100ma'])
ax2.bar(df_LCID.index,df_LCID['Volume'])
# Out:
# <BarContainer object of 235 artists>

# %% [markdown]
# ### Candle chart with volume

# %%
df_ohlc_FSR = df_FSR['Adj Close'].resample('10D').ohlc()
df_volume_FSR = df_FSR['Volume']. resample('10D').sum()

df_ohlc_FSR.reset_index(inplace=True)
df_ohlc_FSR['Date'] =df_ohlc_FSR['Date'].map(mdates.date2num)

ax1 =plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
plt.title('Candle Chart for FSR')
ax2 =plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)
plt.title('Volume for FSR')
ax1.xaxis_date()

candlestick_ohlc(ax1, df_ohlc_FSR.values, width=2, colorup='g')
ax2.fill_between(df_volume_FSR.index.map(mdates.date2num),df_volume_FSR.values,0)
plt.show()

# %%
df_ohlc_GM = df_GM['Adj Close'].resample('10D').ohlc()
df_volume_GM = df_GM['Volume']. resample('10D').sum()

df_ohlc_GM.reset_index(inplace=True)
df_ohlc_GM['Date'] =df_ohlc_GM['Date'].map(mdates.date2num)

ax1 =plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
plt.title('Candle Chart for GM')
ax2 =plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)
plt.title('Volume for GM')
ax1.xaxis_date()

candlestick_ohlc(ax1, df_ohlc_GM.values, width=2, colorup='g')
ax2.fill_between(df_volume_GM.index.map(mdates.date2num),df_volume_GM.values,0)
plt.show()

# %%
df_ohlc_LCID = df_LCID['Adj Close'].resample('10D').ohlc()
df_volume_LCID = df_LCID['Volume']. resample('10D').sum()

df_ohlc_LCID.reset_index(inplace=True)
df_ohlc_LCID['Date'] =df_ohlc_LCID['Date'].map(mdates.date2num)

ax1 =plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
plt.title('Candle Chart for LCID')
ax2 =plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)
plt.title('Volume for LCID')
ax1.xaxis_date()

candlestick_ohlc(ax1, df_ohlc_LCID.values, width=2, colorup='g')
ax2.fill_between(df_volume_LCID.index.map(mdates.date2num),df_volume_LCID.values,0)
plt.show()
