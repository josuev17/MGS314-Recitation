# %% [markdown]
# ## Project 3

# %% [markdown]
# Student Name:
#
# (Double click the cell below to enter your name)

# %% [markdown]
# Josue Quichiz

# %% [markdown]
# 1) Import the packages:

# %%
import pandas as pd
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %% [markdown]
# 2) Pick a style other than 'ggplot':

# %%
style.use('Solarize_Light2')

# %% [markdown]
# 3) Set time parameters for this year:

# %%
start = datetime.datetime(2021, 1, 1)
end = datetime.datetime(2021, 12, 31)

# %% [markdown]
# 4) Pick a stock ticker abbreviation to create a dataframe from downloaded data

# %%
df = web.DataReader('AAPL', 'yahoo', start, end)

# %% [markdown]
# 5) Reset the dataframe variable to read the exported data:

# %%
df.to_csv('aapl.csv')
df = pd.read_csv('aapl.csv', parse_dates=True, index_col=0)

# %% [markdown]
# 6) Print it out to see if it worked

# %%
df
# Out:
#               High     Low    Open   Close    Volume  Adj Close
# Date
# 2021-01-04  133.61  126.76  133.52  129.41  1.43e+08     128.62
# 2021-01-05  131.74  128.43  128.89  131.01  9.77e+07     130.21
# 2021-01-06  131.05  126.38  127.72  126.60  1.55e+08     125.82
# 2021-01-07  131.63  127.86  128.36  130.92  1.10e+08     130.12
# 2021-01-08  132.63  130.23  132.43  132.05  1.05e+08     131.24
# ...            ...     ...     ...     ...       ...        ...
# 2021-11-11  149.43  147.68  148.96  147.87  4.10e+07     147.87
# 2021-11-12  150.40  147.48  148.43  149.99  6.36e+07     149.99
# 2021-11-15  151.88  149.43  150.37  150.00  5.92e+07     150.00
# 2021-11-16  151.49  149.34  149.94  151.00  5.93e+07     151.00
# 2021-11-17  155.00  150.99  150.99  153.49  8.80e+07     153.49
#
# [222 rows x 6 columns]

# %% [markdown]
# 7) Reduce decimal places for easier viewing and print it out to see if that worked

# %%
pd.set_option('display.precision', 2)

# %% [markdown]
# 8) Specify the index as the first column, and print the dataframe:

# %%
df = pd.read_csv('aapl.csv', parse_dates=True, index_col=0)
df
# Out:
#               High     Low    Open   Close    Volume  Adj Close
# Date
# 2021-01-04  133.61  126.76  133.52  129.41  1.43e+08     128.62
# 2021-01-05  131.74  128.43  128.89  131.01  9.77e+07     130.21
# 2021-01-06  131.05  126.38  127.72  126.60  1.55e+08     125.82
# 2021-01-07  131.63  127.86  128.36  130.92  1.10e+08     130.12
# 2021-01-08  132.63  130.23  132.43  132.05  1.05e+08     131.24
# ...            ...     ...     ...     ...       ...        ...
# 2021-11-11  149.43  147.68  148.96  147.87  4.10e+07     147.87
# 2021-11-12  150.40  147.48  148.43  149.99  6.36e+07     149.99
# 2021-11-15  151.88  149.43  150.37  150.00  5.92e+07     150.00
# 2021-11-16  151.49  149.34  149.94  151.00  5.93e+07     151.00
# 2021-11-17  155.00  150.99  150.99  153.49  8.80e+07     153.49
#
# [222 rows x 6 columns]

# %% [markdown]
# 9) Select the LAST two columns and print them out:

# %%
print(df[['Volume', 'Adj Close']])
# Out:
#               Volume  Adj Close
# Date
# 2021-01-04  1.43e+08     128.62
# 2021-01-05  9.77e+07     130.21
# 2021-01-06  1.55e+08     125.82
# 2021-01-07  1.10e+08     130.12
# 2021-01-08  1.05e+08     131.24
# ...              ...        ...
# 2021-11-11  4.10e+07     147.87
# 2021-11-12  6.36e+07     149.99
# 2021-11-15  5.92e+07     150.00
# 2021-11-16  5.93e+07     151.00
# 2021-11-17  8.80e+07     153.49
#
# [222 rows x 2 columns]

# %% [markdown]
# 10) Make a graph from ALL the data

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# 11) Assign a variable to the Adj Close data and plot the data as a graph, add a title, and get rid of the text above the graph

# %%
adjClose = df['Adj Close']
plt.figure(figsize =(12,6))
plt.xlabel('Date')
plt.ylabel('Adjusted closing price ($)')
plt.title('APPL Adj Close')
adjClose.plot();

# %% [markdown]
# 12) Create a 50 day Smimple moving average with no minimum period of calculation

# %%
df['50ma'] = df['Adj Close'].rolling(window=50, min_periods = 0).mean()

# %% [markdown]
# 13) Plot the 50 day moving average, add a title, and get rid of the text above the graph

# %%
sma = df['50ma']
plt.figure(figsize =(12,6))
plt.xlabel('Date')
plt.title('APPL 50 Day Moving Average')
sma.plot();

# %% [markdown]
# 14) Create a graph for this data with a grid size of 12 by 6.
# a) Plot the Adjusted Close and 50 Day Simple Moving Average,
# b) label them and make the line width different for each,
# c) Add labels on the axes,
# d) Add a title,
# e) Add a legend
#
# (20 pts.)

# %%
plt.figure(figsize = (12,6))
plt.plot(adjClose, label = 'APPL Adj Close', linewidth = 1)
plt.plot(sma, label = '50 Day rolling SMA', linewidth = 5)
plt.xlabel('Date')
plt.ylabel('Adjusted closing price ($)')
plt.title('Price with a single Simple Moving Average')
plt.legend();
